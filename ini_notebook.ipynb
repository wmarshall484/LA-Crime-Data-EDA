# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/iniyavan/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['figure']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
df = pd.read_csv("crime_data.csv", parse_dates=['Time Occurred'])
df.columns
# Out:
# Index(['DR Number', 'Date Reported', 'Date Occurred', 'Time Occurred',
#        'Area ID', 'Area Name', 'Reporting District', 'Crime Code',
#        'Crime Code Description', 'MO Codes', 'Victim Age', 'Victim Sex',
#        'Victim Descent', 'Premise Code', 'Premise Description',
#        'Weapon Used Code', 'Weapon Description', 'Status Code',
#        'Status Description', 'Crime Code 1', 'Crime Code 2', 'Crime Code 3',
#        'Crime Code 4', 'Address', 'Cross Street', 'Location '],
#       dtype='object')

# %%
df['date_time'] = pd.to_datetime(df['Date Occurred'] + " " + df['Time Occurred'])

# %%
df['date_time'].dt.weekday_name.head(10)
# Out:
# 0       Monday
# 1       Friday
# 2       Monday
# 3    Wednesday
# 4     Saturday
# 5      Tuesday
# 6    Wednesday
# 7       Sunday
# 8    Wednesday
# 9      Tuesday
# Name: date_time, dtype: object

# %%
import seaborn as sns

def count_rows(rows):
    return len(rows)


#df[['Crime Code Description', 'Victim Age']].groupby('Crime Code Description').count()
m = df.groupby(['Crime Code Description', 'Victim Age']).apply(count_rows).unstack()
